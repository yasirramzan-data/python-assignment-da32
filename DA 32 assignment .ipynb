# %% [markdown]
# # DA_32_ASSIGNMENT_PYTHON

# %%
string_1 = ("HELLO")

# %%
string_2 = ("YASIR")

# %%
print (string_1, string_2)
# Out:
# HELLO YASIR

# %%
string_3 = (", welcome to Python programming")

# %%
print(string_1, string_2, string_3)
# Out:
# HELLO YASIR , welcome to Python programming

# %%
string_full = string_1+ " "+ string_2+ string_3

# %%
print(string_full)
# Out:
# HELLO YASIR, welcome to Python programming

# %%
print(string_full[0])
# Out:
# H

# %%
print(string_full[-1])
# Out:
# g

# %%
print(string_full[:5])
# Out:
# HELLO

# %%
print(string_full[:-11])
# Out:
# HELLO YASIR, welcome to Python

# %%
print(string_full[::-1])
# Out:
# gnimmargorp nohtyP ot emoclew ,RISAY OLLEH

# %%
string_p = ("Python beginner tutorial")

# %%
upper = string_p.upper()

# %%
print(upper)
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
lower = string_p.lower()

# %%
print(lower)
# Out:
# python beginner tutorial

# %%
capitalized = lower.capitalize()

# %%
print(capitalized)
# Out:
# Python beginner tutorial

# %%
count_t = string_p.count("t")

# %%
print(count_t)
# Out:
# 3

# %%
replaced = string_p.replace("Python","MACHINE LEARNING")

# %%
print(replaced)
# Out:
# MACHINE LEARNING beginner tutorial

# %% [markdown]
# ### TUPLE

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)

# %%
combined = t1 + t2

# %%
print (combined)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
repeat = combined * 3

# %%
print(repeat)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(combined[2])
# Out:
# 30

# %%
print(combined[:3])
# Out:
# (10, 20, 30)

# %%
print(combined[:-3])
# Out:
# (10, 20, 30)
